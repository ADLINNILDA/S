# %% [markdown]
# <a href="https://colab.research.google.com/github/ADLINNILDA/S/blob/main/Translate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary packages
# !pip install googletrans==4.0.0-rc1
# !pip install gtts

# Now, import the libraries after installing them
import googletrans
from googletrans import Translator
from gtts import gTTS
import IPython.display as display

# Function to translate text and convert to speech
def translate_and_speak(text, src_lang="en", dest_lang="ta"):  # "ta" for Tamil
    translator = Translator()
    translated_text = translator.translate(text, src=src_lang, dest=dest_lang).text

    print(f"🔹 English: {text}")
    print(f"🔹 Tamil: {translated_text}")

    # Convert text to speech
    tts = gTTS(translated_text, lang=dest_lang)
    tts.save("translated_audio.mp3")

    # Play the audio
    display.display(display.Audio("translated_audio.mp3", autoplay=True))

# Example usage
text_to_translate = "i am happy?"
translate_and_speak(text_to_translate)
# Out:
# ...
# 🔹 English: i am happy?
# 🔹 Tamil: நான் மகிழ்ச்சியாக இருக்கிறேனா?
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
